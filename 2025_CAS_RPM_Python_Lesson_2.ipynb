# %% [markdown]
# <a href="https://colab.research.google.com/github/RuthlessActuary2023/CAS-RPM-2025-Python-Workshop/blob/main/2025_CAS_RPM_Python_Lesson_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 2: Importing, Manipulating, and Analyzing Data

# %% [markdown]
# ### Import pandas and name pd
# ### Set file path and name files
# ### Import .csv files with data

# %%
# Code to clone the github repo into colab
# !pip install gitpython
import git
import os

repo_url = 'https://github.com/RuthlessActuary2023/CAS-RPM-2025-Python-Workshop.git'
repo_dir = '/content/your-repo'

# Clone if it doesn’t already exist
if not os.path.exists(repo_dir):
    git.Repo.clone_from(repo_url, repo_dir)

# %%
import pandas as pd

data1 = pd.read_feather(repo_dir + '/base_data_for_intro_python.ftr')
cfax = pd.read_feather(repo_dir + '/carfax_fields_for_merge.ftr')
geo = pd.read_feather(repo_dir + '/geo_12312019.ftr')

# %% [markdown]
# ### Look at shape of the data -> (rows, columns)

# %%
print(data1.shape)
print(cfax.shape)
print(geo.shape)
# Out:
# (100443, 35)
# (98566, 55)
# (32364, 128)

# %% [markdown]
# ### Use .head() to look at top 5 rows of data.

# %%
data1.head()
# Out:
#   insstate  cbistier vehuse  numveh  numdrv  modlyr  make  model  collsymb  \
# 0       OH         3      P       1     1.0  2010.0   NaN    NaN      12.0
# 1       OH         3      P       1     1.0  2010.0   NaN    NaN      12.0
# 2       OH         4      P       1     1.0  2010.0   NaN    NaN      12.0
# 3       OH         3      P       1     1.0  2010.0   NaN    NaN      12.0
# 4       OH         4      P       1     1.0  2007.0   NaN    NaN      12.0
#
#    perslimbi  ...  cc_col  color_exterior color_interior year_CEF  \
# 0    50000.0  ...       0            None           None   2010.0
# 1    50000.0  ...       0            None           None   2010.0
# 2    50000.0  ...       0            None           None      NaN
# 3    50000.0  ...       0            None           None   2010.0
# 4    50000.0  ...       0            None           None   2007.0
#
#    mDrvGenMarSts  modelyear      rand      zip  pol_id  vin_id
# ...

# %% [markdown]
# ### Use .head(50) to look at first 50 records.

# %%
data1.head(50)
# Out:
#    insstate  cbistier vehuse  numveh  numdrv  modlyr  make  model  collsymb  \
# 0        OH         3      P       1     1.0  2010.0   NaN    NaN      12.0
# 1        OH         3      P       1     1.0  2010.0   NaN    NaN      12.0
# 2        OH         4      P       1     1.0  2010.0   NaN    NaN      12.0
# 3        OH         3      P       1     1.0  2010.0   NaN    NaN      12.0
# 4        OH         4      P       1     1.0  2007.0   NaN    NaN      12.0
# 5        OH         7      W       1     1.0  2013.0   NaN    NaN      32.0
# 6        OH         4      W       1     1.0  2006.0   NaN    NaN      15.0
# 7        OH         4      W       2     1.0  2006.0   NaN    NaN      15.0
# 8        OH         4      W       1     1.0  2006.0   NaN    NaN      15.0
# 9        OH         4      P       2     1.0  2014.0   NaN    NaN      54.0
# 10       OH         9      C       1     1.0     NaN   NaN    NaN      26.0
# ...

# %% [markdown]
# ### Determine count of rows with null value for each field in dataset

# %%
data1.isna().sum()
# Out:
# insstate               0
# cbistier               0
# vehuse               189
# numveh                 0
# numdrv                76
# modlyr             83737
# make              100443
# model             100443
# collsymb              14
# perslimbi             17
# acclimbi               1
# deductiblecol       1570
# pol_eff_date           0
# pol_exp_date           0
# pol_eff_year           0
# DrvAge                60
# DrvSex                62
# DrvMarSts             60
# ep_bi                  0
# ep_col                 0
# ee_bi                  0
# ee_col                 0
# incloss_bi             0
# incloss_col            0
# cc_bi                  0
# cc_col                 0
# color_exterior     56463
# color_interior     54321
# year_CEF            3068
# mDrvGenMarSts       4482
# modelyear           1283
# rand                   0
# zip                    0
# pol_id                 0
# vin_id                 0
# dtype: int64

# %% [markdown]
# ### Review datatypes
# #### For more information about datatypes in python, this website is useful: https://www.geeksforgeeks.org/python-data-types/

# %%
data1.dtypes
# Out:
# insstate           object
# cbistier            int64
# vehuse             object
# numveh              int64
# numdrv            float64
# modlyr            float64
# make              float64
# model             float64
# collsymb          float64
# perslimbi         float64
# acclimbi          float64
# deductiblecol     float64
# pol_eff_date       object
# pol_exp_date       object
# pol_eff_year        int64
# DrvAge            float64
# DrvSex             object
# DrvMarSts          object
# ep_bi             float64
# ep_col            float64
# ee_bi             float64
# ee_col            float64
# incloss_bi        float64
# incloss_col       float64
# cc_bi               int64
# cc_col              int64
# color_exterior     object
# color_interior     object
# year_CEF          float64
# mDrvGenMarSts      object
# modelyear         float64
# rand              float64
# zip               float64
# pol_id              int64
# vin_id              int64
# dtype: object

# %% [markdown]
# ### Switch datatype of pol_eff_date from object to a date
# ### Show a random sample of 25 of just the pol_eff_date column using [([])]

# %%
data1['pol_eff_date'] = pd.to_datetime(data1['pol_eff_date'], infer_datetime_format = True)

data1[(['pol_eff_date'])].sample(n = 25)
# Out:
# <ipython-input-8-37731efda006>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   data1['pol_eff_date'] = pd.to_datetime(data1['pol_eff_date'], infer_datetime_format = True)
#       pol_eff_date
# 42170   2017-11-03
# 22949   2015-12-11
# 7742    2017-08-25
# 14727   2015-12-26
# 90332   2017-09-23
# 81797   2019-04-24
# 71558   2016-04-17
# 61147   2019-01-28
# 78737   2015-10-13
# 16213   2016-07-15
# 54889   2015-06-22
# 98142   2018-12-18
# 27378   2017-07-22
# 29466   2016-11-22
# 86443   2019-02-18
# 14701   2018-08-01
# 89701   2019-02-28
# 7351    2016-06-16
# 89562   2018-07-12
# 33759   2017-12-03
# 30030   2016-05-02
# 46034   2017-11-19
# 6156    2018-02-06
# 21568   2019-08-06
# 10401   2017-02-24

# %% [markdown]
# # View min, mean, max of all numeric variables and export to clipboard for excel

# %% [markdown]
# ### Import numpy
# ### Identify the datatypes for each field by creating a dataframe with field name and dtype

# %%
import numpy as np

a = data1.dtypes.reset_index()

a.head()
# Out:
#       index        0
# 0  insstate   object
# 1  cbistier    int64
# 2    vehuse   object
# 3    numveh    int64
# 4    numdrv  float64

# %% [markdown]
# ### Rename the columns

# %%
a.rename(columns = {'index': 'field', 0: 'dtype'}, inplace = True)

a.head()
# Out:
#       field    dtype
# 0  insstate   object
# 1  cbistier    int64
# 2    vehuse   object
# 3    numveh    int64
# 4    numdrv  float64

# %% [markdown]
# ### Filter using .loc to only those which are not strings and make a new df as a copy
# #### Helpful Hint: Creating a copy of a df is usually done to avoid errors later

# %%
numerics = a.loc[a['dtype'] != 'object'].copy()

numerics.head()
# Out:
#       field    dtype
# 1  cbistier    int64
# 3    numveh    int64
# 4    numdrv  float64
# 5    modlyr  float64
# 6      make  float64

# %% [markdown]
# ### As a quick check, use groupby to see the dtypes and count

# %%
numerics.groupby(['dtype']).count().reset_index()
# Out:
#             dtype  field
# 0           int64      7
# 1         float64     19
# 2  datetime64[ns]      1

# %% [markdown]
# ### Remove the dtype column by using .drop()
# ### Create columns for min, mean, and max by looping through a defined list and inserting NaN for all values to start

# %%
numerics.drop(columns = 'dtype', inplace = True)

fields = ['min','mean','max']
for f in fields:
    numerics[f] = np.nan

numerics
# Out:
#             field  min  mean  max
# 1        cbistier  NaN   NaN  NaN
# 3          numveh  NaN   NaN  NaN
# 4          numdrv  NaN   NaN  NaN
# 5          modlyr  NaN   NaN  NaN
# 6            make  NaN   NaN  NaN
# 7           model  NaN   NaN  NaN
# 8        collsymb  NaN   NaN  NaN
# 9       perslimbi  NaN   NaN  NaN
# 10       acclimbi  NaN   NaN  NaN
# 11  deductiblecol  NaN   NaN  NaN
# 12   pol_eff_date  NaN   NaN  NaN
# 14   pol_eff_year  NaN   NaN  NaN
# 15         DrvAge  NaN   NaN  NaN
# 18          ep_bi  NaN   NaN  NaN
# 19         ep_col  NaN   NaN  NaN
# 20          ee_bi  NaN   NaN  NaN
# 21         ee_col  NaN   NaN  NaN
# 22     incloss_bi  NaN   NaN  NaN
# 23    incloss_col  NaN   NaN  NaN
# 24          cc_bi  NaN   NaN  NaN
# 25         cc_col  NaN   NaN  NaN
# 28       year_CEF  NaN   NaN  NaN
# 30      modelyear  NaN   NaN  NaN
# 31           rand  NaN   NaN  NaN
# 32            zip  NaN   NaN  NaN
# 33         pol_id  NaN   NaN  NaN
# ...

# %% [markdown]
# ### Create a list of all values in numerics['field'] using .to_list()

# %%
numerics_list = numerics['field'].to_list()

numerics_list
# Out:
# ['cbistier',
#  'numveh',
#  'numdrv',
#  'modlyr',
#  'make',
#  'model',
#  'collsymb',
#  'perslimbi',
#  'acclimbi',
#  'deductiblecol',
#  'pol_eff_date',
#  'pol_eff_year',
#  'DrvAge',
#  'ep_bi',
#  'ep_col',
#  'ee_bi',
#  'ee_col',
#  'incloss_bi',
#  'incloss_col',
#  'cc_bi',
#  'cc_col',
#  'year_CEF',
#  'modelyear',
#  'rand',
#  'zip',
#  'pol_id',
#  'vin_id']

# %% [markdown]
# ### Loop over rows and columns to populate the table
# #### Helpful Hint: You can produce a loop within a loop when you want to loop through multiple lists

# %%
numerics_list = numerics['field'].to_list()

for n in numerics_list:
    for f in fields:
        nxt = numerics['field'] == n
        if f == 'min':
            numerics.loc[nxt,f] = data1[n].min()
        if f == 'mean':
            numerics.loc[nxt,f] = data1[n].mean()
        if f == 'max':
            numerics.loc[nxt,f] = data1[n].max()

numerics
# Out:
# <ipython-input-15-ac45a181a7e1>:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2014-01-01 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   numerics.loc[nxt,f] = data1[n].min()
# <ipython-input-15-ac45a181a7e1>:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2017-04-09 12:49:02.277709824' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   numerics.loc[nxt,f] = data1[n].mean()
# <ipython-input-15-ac45a181a7e1>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2019-12-31 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   numerics.loc[nxt,f] = data1[n].max()
# ...

# %% [markdown]
# ### Copy to clipboard using .to_clipboard and view in Excel

# %%
# numerics.to_clipboard(excel = True, index = False) # does not work in colab, keep here for reference

# %% [markdown]
# # Create function for analyzing data

# %% [markdown]
# ### Use .groupby() and .agg to view some data in data1

# %%
data1.groupby(['cbistier']).agg({'ee_bi': 'sum'}).reset_index()
# Out:
#     cbistier        ee_bi
# 0          0   649.130055
# 1          1  5860.327075
# 2          2  6993.019972
# 3          3  6648.480358
# 4          4  6190.745894
# 5          5  6235.280148
# 6          6  5920.227068
# 7          7  5706.139150
# 8          8  5037.354465
# 9          9  4160.333296
# 10        10  2911.364578
# 11        90   117.191377
# 12        99    68.390995

# %% [markdown]
# ### Create pct_of_tot field

# %%
a = data1.groupby(['cbistier']).agg({'ee_bi': 'sum'}).reset_index()
a['pct_of_tot'] = a['ee_bi']/a['ee_bi'].sum()
a
# Out:
#     cbistier        ee_bi  pct_of_tot
# 0          0   649.130055    0.011489
# 1          1  5860.327075    0.103726
# 2          2  6993.019972    0.123775
# 3          3  6648.480358    0.117676
# 4          4  6190.745894    0.109575
# 5          5  6235.280148    0.110363
# 6          6  5920.227068    0.104787
# 7          7  5706.139150    0.100997
# 8          8  5037.354465    0.089160
# 9          9  4160.333296    0.073637
# 10        10  2911.364578    0.051530
# 11        90   117.191377    0.002074
# 12        99    68.390995    0.001211

# %% [markdown]
# ### Create a list comprehension to find the metrics we need
# #### Helpful Hint: List comprehension is a good way to create lists
# #### [expression for item in iterable if condition]

# %%
facts = [i for i in data1.columns if 'ee_' in i or 'ep_' in i or 'incloss_' in i or 'cc_' in i]
facts
# Out:
# ['ep_bi',
#  'ep_col',
#  'ee_bi',
#  'ee_col',
#  'incloss_bi',
#  'incloss_col',
#  'cc_bi',
#  'cc_col']

# %% [markdown]
# ### Define agg_dict
# ### Create a function eda_table0 that loops through the facts list and produces a table of aggregated data.

# %%
agg_dict = {i: 'sum' for i in facts}

def eda_table0(data,field):
    a = data.groupby([field], dropna = False).agg(agg_dict).reset_index()

    for f in facts:
        a[f + '_pct'] = a[f]/a[f].sum()

    return a

# %% [markdown]
# ### Set Display Settings to determine the number of columns and rows viewed and the size of the display.
#
# ### Run eda_table0 function on data1 dataset for cbistier

# %%
pd.set_option("display.max_columns",25)
pd.set_option("display.max_rows",250)
pd.options.display.float_format = '{:,.2f}'.format

from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 90%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

eda_table0(data1,'cbistier')
# Out:
# <style>
#     div#notebook-container    { width: 90%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
#     cbistier        ep_bi       ep_col    ee_bi   ee_col   incloss_bi  \
# 0          0   116,195.14   186,000.97   649.13   649.13    33,097.00
# 1          1   845,094.50 1,324,559.47 5,860.33 5,860.33   938,001.18
# 2          2   985,485.00 1,555,607.09 6,993.02 6,993.02   275,257.88
# 3          3 1,024,569.80 1,620,210.56 6,648.48 6,648.48   558,796.93
# 4          4 1,045,432.40 1,635,138.07 6,190.75 6,190.75   504,033.64
# 5          5 1,055,598.13 1,704,023.27 6,235.28 6,235.28   436,522.38
# 6          6 1,050,536.31 1,736,862.38 5,920.23 5,920.23   741,131.17
# 7          7 1,077,200.44 1,792,036.45 5,706.14 5,706.14   295,590.25
# 8          8 1,004,587.53 1,695,278.16 5,037.35 5,037.35   454,016.81
# 9          9   911,828.95 1,542,546.59 4,160.33 4,160.33 1,084,569.27
# ...

# %% [markdown]
# ### Create a more specific function, eda_table

# %%
facts = [i for i in data1.columns if 'ee_' in i or 'ep_' in i or 'incloss_' in i or 'cc_' in i]
ee_list = [i for i in data1.columns if 'ee_' in i]
agg_dict = {i: 'sum' for i in facts}

covs = ['bi','col']

def eda_table(data,field):
    a = data.groupby([field], dropna = False).agg(agg_dict).reset_index()

    for e in ee_list:
        a[e + '_pct'] = a[e]/a[e].sum()

    for c in covs:
        a['avg_prem_' + c] = a['ep_' + c]/a['ee_' + c]
        a['lr_' + c] = a['incloss_' + c]/a['ep_' + c]
        a['freq_' + c] = a['cc_' + c]/a['ee_' + c]
        a['sev_' + c] = a['incloss_' + c]/a['cc_' + c]
        a['pp_' + c] = a['incloss_' + c]/a['ee_' + c]

    a.drop(columns = facts, inplace = True)
#     a = a.drop(columns = facts)

    return a

# %% [markdown]
# ### Run eda_table function on data1 for cbistier

# %%
eda_table(data1,'cbistier')
# Out:
#     cbistier  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0          0       0.01        0.01       179.00   0.28     0.00 11,032.33
# 1          1       0.10        0.10       144.21   1.11     0.00 39,083.38
# 2          2       0.12        0.12       140.92   0.28     0.00 13,762.89
# 3          3       0.12        0.12       154.11   0.55     0.00 16,933.24
# 4          4       0.11        0.11       168.87   0.48     0.01 13,264.04
# 5          5       0.11        0.11       169.29   0.41     0.01 12,125.62
# 6          6       0.10        0.10       177.45   0.71     0.01 22,458.52
# 7          7       0.10        0.10       188.78   0.27     0.01  7,778.69
# 8          8       0.09        0.09       199.43   0.45     0.01 11,350.42
# 9          9       0.07        0.07       219.17   1.19     0.01 23,075.94
# 10        10       0.05        0.05       228.59   0.47     0.01 14,795.56
# ...

# %% [markdown]
# ### Create a loop to run data1 through eda_table function for all j in list comprehension
#
# #### Hint: Use print('------') at end of loop segment each iteration in the display

# %%
for j in [i for i in data1.columns if i not in facts]:
    display(eda_table(data1,j))
    print('-------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
#   insstate  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0       OH       1.00        1.00       173.82   0.57     0.01 16,912.08
#
#    pp_bi  avg_prem_col  lr_col  freq_col  sev_col  pp_col
# 0  99.68        284.81    0.48      0.04 3,732.69  138.08
# -------------------------------------------------------------------------------------------------------------------------------------------------
#     cbistier  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0          0       0.01        0.01       179.00   0.28     0.00 11,032.33
# 1          1       0.10        0.10       144.21   1.11     0.00 39,083.38
# 2          2       0.12        0.12       140.92   0.28     0.00 13,762.89
# 3          3       0.12        0.12       154.11   0.55     0.00 16,933.24
# 4          4       0.11        0.11       168.87   0.48     0.01 13,264.04
# 5          5       0.11        0.11       169.29   0.41     0.01 12,125.62
# ...

# %% [markdown]
# ### Create function that drop duplicates and returns the number of unique rows.

# %%
def unique_non_null(data,field):
    a = data.loc[data[field].isna() == False][([field])].drop_duplicates()
    return a.shape[0]

unique_non_null(data1,'cbistier')
# Out:
# 13

# %% [markdown]
# ### Create an empty dataframe named useless_fields
#
# ### Loop through columns in data1, determine and print which fields are useless, and add those fields that have 1 or less rows to useless_fields dataframe

# %%
useless_fields = []

for j in [i for i in data1.columns if i not in facts]:
    if unique_non_null(data1,j) <= 1:
        print(j + ' has 1 or less rows')
        useless_fields.append(j)
# Out:
# insstate has 1 or less rows
# make has 1 or less rows
# model has 1 or less rows

# %% [markdown]
# ### Check shape of data1 before and after dropping useless_fields to ensure it was done correctly
#
# #### How does this ensure that we have removed the fields correctly?

# %%
print(data1.shape)
data1.drop(columns = useless_fields, inplace = True)
print(data1.shape)
# Out:
# (100443, 35)
# (100443, 32)

# %% [markdown]
# ## Group feature levels as new features in dataset

# %% [markdown]
# ### Below we will use the function now to perform EDA on this dataset
#
# ### Use a list comprehension to determine which fields to analyze

# %%
stuff_to_analyze = [i for i in data1.columns if i not in facts]
stuff_to_analyze
# Out:
# ['cbistier',
#  'vehuse',
#  'numveh',
#  'numdrv',
#  'modlyr',
#  'collsymb',
#  'perslimbi',
#  'acclimbi',
#  'deductiblecol',
#  'pol_eff_date',
#  'pol_exp_date',
#  'pol_eff_year',
#  'DrvAge',
#  'DrvSex',
#  'DrvMarSts',
#  'color_exterior',
#  'color_interior',
#  'year_CEF',
#  'mDrvGenMarSts',
#  'modelyear',
#  'rand',
#  'zip',
#  'pol_id',
#  'vin_id']

# %% [markdown]
# ### Use eda_table function to assess cbistier

# %%
eda_table(data1,'cbistier')
# Out:
#     cbistier  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0          0       0.01        0.01       179.00   0.28     0.00 11,032.33
# 1          1       0.10        0.10       144.21   1.11     0.00 39,083.38
# 2          2       0.12        0.12       140.92   0.28     0.00 13,762.89
# 3          3       0.12        0.12       154.11   0.55     0.00 16,933.24
# 4          4       0.11        0.11       168.87   0.48     0.01 13,264.04
# 5          5       0.11        0.11       169.29   0.41     0.01 12,125.62
# 6          6       0.10        0.10       177.45   0.71     0.01 22,458.52
# 7          7       0.10        0.10       188.78   0.27     0.01  7,778.69
# 8          8       0.09        0.09       199.43   0.45     0.01 11,350.42
# 9          9       0.07        0.07       219.17   1.19     0.01 23,075.94
# 10        10       0.05        0.05       228.59   0.47     0.01 14,795.56
# ...

# %% [markdown]
# ### 90 and 99 are no hit/no score - let's put them in with the "base level" and call them 5.  Let's also rename this field.
#
# #### How can we tell that the field is renamed? Does cbistier still exist at this time?

# %%
data1['credit'] = np.where(data1['cbistier'] > 10, 5, data1['cbistier'])

eda_table(data1,'credit')
# Out:
#     credit  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0        0       0.01        0.01       179.00   0.28     0.00 11,032.33
# 1        1       0.10        0.10       144.21   1.11     0.00 39,083.38
# 2        2       0.12        0.12       140.92   0.28     0.00 13,762.89
# 3        3       0.12        0.12       154.11   0.55     0.00 16,933.24
# 4        4       0.11        0.11       168.87   0.48     0.01 13,264.04
# 5        5       0.11        0.11       170.40   0.40     0.01 12,125.62
# 6        6       0.10        0.10       177.45   0.71     0.01 22,458.52
# 7        7       0.10        0.10       188.78   0.27     0.01  7,778.69
# 8        8       0.09        0.09       199.43   0.45     0.01 11,350.42
# 9        9       0.07        0.07       219.17   1.19     0.01 23,075.94
# 10      10       0.05        0.05       228.59   0.47     0.01 14,795.56
#
#     pp_bi  avg_prem_col  lr_col  freq_col  sev_col  pp_col
# ...

# %% [markdown]
# ### Create a blank list named remove_list
# ### Add cbistier to remove_list
# ### Use remove() to cbistier from stuff_to_analyze

# %%
remove_list = []
remove_list.append('cbistier')

stuff_to_analyze.remove('cbistier')

# %% [markdown]
# ### View fields that still need to be analyzed

# %%
stuff_to_analyze
# Out:
# ['vehuse',
#  'numveh',
#  'numdrv',
#  'modlyr',
#  'collsymb',
#  'perslimbi',
#  'acclimbi',
#  'deductiblecol',
#  'pol_eff_date',
#  'pol_exp_date',
#  'pol_eff_year',
#  'DrvAge',
#  'DrvSex',
#  'DrvMarSts',
#  'color_exterior',
#  'color_interior',
#  'year_CEF',
#  'mDrvGenMarSts',
#  'modelyear',
#  'rand',
#  'zip',
#  'pol_id',
#  'vin_id']

# %% [markdown]
# ### Use eda_table function to assess vehuse

# %%
eda_table(data1,'vehuse')
# Out:
#   vehuse  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  pp_bi  \
# 0      B       0.00        0.00       228.34   0.41     0.01  7,973.67  93.12
# 1      C       0.42        0.42       186.90   0.60     0.01 18,058.02 112.77
# 2      F       0.01        0.01       125.78   0.00     0.00       NaN   0.00
# 3      P       0.53        0.53       167.04   0.56     0.01 16,963.67  92.81
# 4      W       0.03        0.03       126.27   0.66     0.01  9,132.68  82.82
# 5    NaN       0.00        0.00       136.08   0.31     0.01  3,525.00  42.38
#
#    avg_prem_col  lr_col  freq_col  sev_col  pp_col
# 0        278.71    0.77      0.04 5,018.26  214.90
# 1        303.03    0.51      0.04 4,009.36  155.48
# 2        195.25    0.29      0.01 5,082.01   55.87
# 3        274.13    0.45      0.04 3,436.54  123.36
# 4        254.17    0.70      0.04 4,361.10  177.96
# 5        291.69    0.29      0.03 2,846.00   85.55

# %% [markdown]
# ### Since Business and Farm are such low exposures, let's ignore those
# ### Let's assume W is a data issue and stands for 'Work' and make a flag for C & W and call it commute_flag
# ### Add vehuse to remove_list and remove it from stuff_to_analyze

# %%
data1['commute_flag'] = np.where(data1['vehuse'].isin(['C','W']) == True, True, False)
remove_list.append('vehuse')
stuff_to_analyze.remove('vehuse')

eda_table(data1,'commute_flag')
# Out:
#    commute_flag  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0         False       0.55        0.55       166.53   0.54     0.01 16,645.05
# 1          True       0.45        0.45       182.70   0.61     0.01 17,187.25
#
#    pp_bi  avg_prem_col  lr_col  freq_col  sev_col  pp_col
# 0  90.64        272.65    0.45      0.04 3,460.17  122.53
# 1 110.70        299.64    0.52      0.04 4,034.92  157.04

# %% [markdown]
# ### View fields that still need to be analyzed

# %%
stuff_to_analyze
# Out:
# ['numveh',
#  'numdrv',
#  'modlyr',
#  'collsymb',
#  'perslimbi',
#  'acclimbi',
#  'deductiblecol',
#  'pol_eff_date',
#  'pol_exp_date',
#  'pol_eff_year',
#  'DrvAge',
#  'DrvSex',
#  'DrvMarSts',
#  'color_exterior',
#  'color_interior',
#  'year_CEF',
#  'mDrvGenMarSts',
#  'modelyear',
#  'rand',
#  'zip',
#  'pol_id',
#  'vin_id']

# %% [markdown]
# ### Use eda_table function to assess numveh

# %%
eda_table(data1,'numveh')
# Out:
#     numveh  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi     sev_bi  \
# 0        1       0.21        0.21       210.25   0.43     0.01  10,863.91
# 1        2       0.39        0.39       154.86   0.62     0.01  18,664.39
# 2        3       0.23        0.23       165.70   0.48     0.01  13,992.41
# 3        4       0.11        0.11       187.66   0.43     0.01  14,800.64
# 4        5       0.04        0.04       184.69   1.95     0.01  71,515.25
# 5        6       0.01        0.01       156.31   0.92     0.00 100,000.00
# 6        7       0.00        0.00       179.04   0.00     0.00        NaN
# 7        8       0.00        0.00       114.76   0.00     0.00        NaN
# 8        9       0.00        0.00       138.04   0.00     0.00        NaN
# 9       10       0.00        0.00        82.68   0.00     0.00        NaN
# 10      11       0.00        0.00        60.50   0.00     0.00        NaN
# 11      12       0.00        0.00       148.00   0.00     0.00        NaN
#
# ...

# %% [markdown]
# ### We're getting tired of repetitive tasks, let's make a function that creates a new field in the data with a suffix "_box" that will reduce the range of numeric fields
#
# ### Now that we have several examples above, guess what the cells below are attempting to do, run the cell, and determine whether you understood the code.

# %%
def box_var(data, field, low, high, new_name = False):
    if new_name == False:
        data[field] = np.where(data[field] <= low, low, np.where(data[field] >= high, high, data[field]))
    else:
        data[new_name] = np.where(data[field] <= low, low, np.where(data[field] >= high, high, data[field]))

box_var(data1,'numveh',1,4, new_name = 'veh_count_box')

remove_list.append('numveh')
stuff_to_analyze.remove('numveh')

eda_table(data1,'veh_count_box')
# Out:
#    veh_count_box  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi  \
# 0              1       0.21        0.21       210.25   0.43     0.01
# 1              2       0.39        0.39       154.86   0.62     0.01
# 2              3       0.23        0.23       165.70   0.48     0.01
# 3              4       0.17        0.17       183.68   0.80     0.00
#
#      sev_bi  pp_bi  avg_prem_col  lr_col  freq_col  sev_col  pp_col
# 0 10,863.91  89.69        343.30    0.55      0.05 3,914.62  188.97
# 1 18,664.39  96.51        262.15    0.48      0.04 3,453.64  125.95
# 2 13,992.41  79.62        268.84    0.44      0.03 3,731.40  117.48
# 3 30,214.99 147.84        286.52    0.46      0.03 4,137.57  131.16

# %%
stuff_to_analyze
# Out:
# ['numdrv',
#  'modlyr',
#  'collsymb',
#  'perslimbi',
#  'acclimbi',
#  'deductiblecol',
#  'pol_eff_date',
#  'pol_exp_date',
#  'pol_eff_year',
#  'DrvAge',
#  'DrvSex',
#  'DrvMarSts',
#  'color_exterior',
#  'color_interior',
#  'year_CEF',
#  'mDrvGenMarSts',
#  'modelyear',
#  'rand',
#  'zip',
#  'pol_id',
#  'vin_id']

# %%
eda_table(data1,'numdrv')
# Out:
#     numdrv  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0     1.00       0.22        0.22       179.51   0.72     0.01 19,141.10
# 1     2.00       0.53        0.53       143.39   0.35     0.00 10,658.36
# 2     3.00       0.15        0.15       210.01   0.88     0.01 26,052.91
# 3     4.00       0.08        0.08       260.32   0.69     0.01 20,205.85
# 4     5.00       0.02        0.02       325.27   0.42     0.01 19,940.88
# 5     6.00       0.00        0.00       264.64   0.16     0.01  5,000.00
# 6     7.00       0.00        0.00       325.08   0.00     0.00       NaN
# 7     9.00       0.00        0.00        66.10   0.00     0.00       NaN
# 8    10.00       0.00        0.00        83.78   0.00     0.00       NaN
# 9    11.00       0.00        0.00        78.37   0.00     0.00       NaN
# 10   13.00       0.00        0.00       132.01   0.00     0.00       NaN
# 11     NaN       0.00        0.00       127.77   0.00     0.00       NaN
#
# ...

# %% [markdown]
# ### We need to fill in the null value. Let's make a function which uses the modal value unless otherwise specified

# %%
def fillna(data, field, new_name, specific_value = False):
    if specific_value == False:
        data[new_name] = data[field].fillna(data[field].mode().values[0])
    else:
        data[new_name] = data[field].fillna(specific_value)

fillna(data1, 'numdrv', 'numdrv2')

eda_table(data1,'numdrv2')
# Out:
#     numdrv2  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0      1.00       0.22        0.22       179.51   0.72     0.01 19,141.10
# 1      2.00       0.53        0.53       143.37   0.35     0.00 10,658.36
# 2      3.00       0.15        0.15       210.01   0.88     0.01 26,052.91
# 3      4.00       0.08        0.08       260.32   0.69     0.01 20,205.85
# 4      5.00       0.02        0.02       325.27   0.42     0.01 19,940.88
# 5      6.00       0.00        0.00       264.64   0.16     0.01  5,000.00
# 6      7.00       0.00        0.00       325.08   0.00     0.00       NaN
# 7      9.00       0.00        0.00        66.10   0.00     0.00       NaN
# 8     10.00       0.00        0.00        83.78   0.00     0.00       NaN
# 9     11.00       0.00        0.00        78.37   0.00     0.00       NaN
# 10    13.00       0.00        0.00       132.01   0.00     0.00       NaN
#
#     pp_bi  avg_prem_col  lr_col  freq_col  sev_col  pp_col
# ...

# %%
box_var(data1,'numdrv2',1,4, new_name = 'driver_count_box')

remove_list.append('numdrv')
remove_list.append('numdrv2')

stuff_to_analyze.remove('numdrv')

eda_table(data1,'driver_count_box')
# Out:
#    driver_count_box  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi  \
# 0              1.00       0.22        0.22       179.51   0.72     0.01
# 1              2.00       0.53        0.53       143.37   0.35     0.00
# 2              3.00       0.15        0.15       210.01   0.88     0.01
# 3              4.00       0.10        0.10       271.06   0.62     0.01
#
#      sev_bi  pp_bi  avg_prem_col  lr_col  freq_col  sev_col  pp_col
# 0 19,141.10 129.09        302.01    0.60      0.04 4,221.33  180.53
# 1 10,658.36  50.28        244.99    0.47      0.03 3,416.69  115.80
# 2 26,052.91 185.31        328.86    0.44      0.04 3,812.81  143.16
# 3 19,840.72 168.05        394.50    0.39      0.04 3,875.93  154.16

# %%
stuff_to_analyze
# Out:
# ['modlyr',
#  'collsymb',
#  'perslimbi',
#  'acclimbi',
#  'deductiblecol',
#  'pol_eff_date',
#  'pol_exp_date',
#  'pol_eff_year',
#  'DrvAge',
#  'DrvSex',
#  'DrvMarSts',
#  'color_exterior',
#  'color_interior',
#  'year_CEF',
#  'mDrvGenMarSts',
#  'modelyear',
#  'rand',
#  'zip',
#  'pol_id',
#  'vin_id']

# %%
eda_table(data1,'modlyr')
# Out:
#      modlyr  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0  1,949.00       0.00        0.00        28.27   0.00     0.00       NaN
# 1  1,952.00       0.00        0.00        95.86   0.00     0.00       NaN
# 2  1,964.00       0.00        0.00        39.89   0.00     0.00       NaN
# 3  1,965.00       0.00        0.00        68.25   0.00     0.00       NaN
# 4  1,967.00       0.00        0.00        29.14   0.00     0.00       NaN
# 5  1,968.00       0.00        0.00        37.01   0.00     0.00       NaN
# 6  1,969.00       0.00        0.00        40.43   0.00     0.00       NaN
# 7  1,971.00       0.00        0.00        82.69   0.00     0.00       NaN
# 8  1,973.00       0.00        0.00        55.14   0.00     0.00       NaN
# 9  1,974.00       0.00        0.00       130.91   0.00     0.00       NaN
# 10 1,976.00       0.00        0.00        69.43   0.00     0.00       NaN
# 11 1,977.00       0.00        0.00        99.18   0.00     0.00       NaN
# ...

# %% [markdown]
# ### Looks like this field isn't well populated. Let's see if 'modelyear is better

# %%
eda_table(data1,'modelyear')
# Out:
#     modelyear  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0    1,949.00       0.00        0.00        28.27   0.00     0.00       NaN
# 1    1,952.00       0.00        0.00        95.86   0.00     0.00       NaN
# 2    1,964.00       0.00        0.00        39.89   0.00     0.00       NaN
# 3    1,965.00       0.00        0.00        68.25   0.00     0.00       NaN
# 4    1,967.00       0.00        0.00        29.14   0.00     0.00       NaN
# 5    1,968.00       0.00        0.00        37.01   0.00     0.00       NaN
# 6    1,969.00       0.00        0.00        40.43   0.00     0.00       NaN
# 7    1,971.00       0.00        0.00        82.69   0.00     0.00       NaN
# 8    1,973.00       0.00        0.00        55.14   0.00     0.00       NaN
# 9    1,974.00       0.00        0.00       130.91   0.00     0.00       NaN
# 10   1,976.00       0.00        0.00        69.43   0.00     0.00       NaN
# ...

# %% [markdown]
# ### It is, so let's use that instead and get rid of modlyr.
# #### Hint: using del is another way to remove columns

# %%
print(data1.shape)
del data1['modlyr']
stuff_to_analyze.remove('modlyr')
print(data1.shape)
# Out:
# (100443, 37)
# (100443, 36)

# %% [markdown]
# ### Model year isn't useful alone, let's see what the policy year looks like

# %%
eda_table(data1,'pol_eff_year')
# Out:
#    pol_eff_year  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0          2014       0.04        0.04       106.08   0.54     0.01  8,375.68
# 1          2015       0.20        0.20       159.65   0.77     0.01 20,053.10
# 2          2016       0.20        0.20       165.96   0.59     0.01 17,395.65
# 3          2017       0.20        0.20       175.37   0.77     0.01 19,199.19
# 4          2018       0.19        0.19       185.52   0.39     0.00 15,361.34
# 5          2019       0.17        0.17       202.21   0.36     0.01 12,839.80
#
#    pp_bi  avg_prem_col  lr_col  freq_col  sev_col  pp_col
# 0  57.28        202.03    0.58      0.04 3,141.93  118.18
# 1 123.18        262.07    0.48      0.04 3,284.56  125.66
# 2  98.09        284.80    0.47      0.04 3,553.75  133.69
# 3 134.54        293.35    0.53      0.04 4,181.90  155.06
# 4  72.70        295.41    0.43      0.04 3,461.27  125.58
# 5  72.69        310.73    0.51      0.04 4,466.45  157.44

# %%
data1['veh_age'] = data1['pol_eff_year'] - data1['modelyear']

eda_table(data1,'veh_age')
# Out:
#     veh_age  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0     -2.00       0.00        0.00        18.52   0.00     0.00       NaN
# 1     -1.00       0.02        0.02        76.71   6.47     0.01 77,583.03
# 2      0.00       0.07        0.07       145.89   0.95     0.01 25,726.96
# 3      1.00       0.08        0.08       171.67   0.13     0.00  5,704.09
# 4      2.00       0.08        0.08       169.36   0.87     0.01 17,818.16
# 5      3.00       0.07        0.07       171.47   0.49     0.01 11,402.69
# 6      4.00       0.07        0.07       178.74   0.38     0.01 12,586.31
# 7      5.00       0.06        0.06       182.00   0.67     0.01 17,190.54
# 8      6.00       0.06        0.06       182.46   0.30     0.01  9,736.20
# 9      7.00       0.06        0.06       182.38   0.28     0.00 10,088.38
# 10     8.00       0.06        0.06       186.03   0.25     0.01  8,600.17
# 11     9.00       0.05        0.05       190.16   0.46     0.01 15,522.03
# ...

# %% [markdown]
# ### Lets box this between 0 and 15 and fill the null value

# %%
box_var(data1,'veh_age',0,15)

remove_list.append('modelyear')
# stuff_to_analyze.remove('modelyear')

fillna(data1, 'veh_age_box', 'veh_age_box') # generates an error - how do we trouble shoot this?

remove_list.append('veh_age')

eda_table(data1,'veh_age_box')
# Out:
#     veh_age_box  ee_bi_pct  ee_col_pct  avg_prem_bi  lr_bi  freq_bi    sev_bi  \
# 0          0.00       0.09        0.09       129.75   1.68     0.01 39,171.13
# 1          1.00       0.08        0.08       171.67   0.13     0.00  5,704.09
# 2          2.00       0.08        0.08       169.36   0.87     0.01 17,818.16
# 3          3.00       0.07        0.07       171.47   0.49     0.01 11,402.69
# 4          4.00       0.07        0.07       178.74   0.38     0.01 12,586.31
# 5          5.00       0.06        0.06       182.00   0.67     0.01 17,190.54
# 6          6.00       0.06        0.06       182.46   0.30     0.01  9,736.20
# 7          7.00       0.06        0.06       182.38   0.28     0.00 10,088.38
# 8          8.00       0.06        0.06       186.03   0.25     0.01  8,600.17
# 9          9.00       0.05        0.05       190.16   0.46     0.01 15,522.03
# 10        10.00       0.05        0.05       184.37   0.71     0.01 18,360.68
# ...

# %%
stuff_to_analyze

# %% [markdown]
# # Group Work:
# ### The following creates a percentile of collision symbol by model year group.

# %%
eda_table(data1,'collsymb')

# %%
eda_table(data1,'modelyear')

# %% [markdown]
# ### Collision Symbol varies by model year group
# ### Let's create the applicable model year groups and look at the data

# %%
data1['my_group'] = '00: Unknown'
nxt = data1['modelyear'] < 9999
data1.loc[nxt,'my_group'] = '03: 2011+'
nxt = data1['modelyear'] <= 2010
data1.loc[nxt,'my_group'] = '02: 1990 to 2010'
nxt = data1['modelyear'] < 1990
data1.loc[nxt,'my_group'] = '01: <1990'

data1.groupby(['my_group','collsymb']).agg({'ee_col': 'sum'}).reset_index()

# %% [markdown]
# ### In practice we would probably use the indicated ISO symbol factor from their filing
# ### For our purposes, let's create a percentile within each my_group and use that as a simple metric

# %%
y = data1.groupby(['my_group','collsymb']).agg({'ee_col': 'sum'}).reset_index()
y['coll_symb_cumsum'] = y.groupby(['my_group']).ee_col.cumsum()
y

# %%
z = y.groupby(['my_group']).agg({'ee_col': 'sum'}).reset_index()
z.rename(columns = {'ee_col': 'my_group_tot'}, inplace = True)

z

# %%
y2 = y.merge(z, on = ['my_group'])

print(y.shape[0])
print(y2.shape[0])

y2

# %%
y2['coll_symb_ntile'] = round(round(y2['coll_symb_cumsum']/y2['my_group_tot'],2)*100,0)

y2

# %%
y3 = y2[(['my_group','collsymb','coll_symb_ntile'])].copy()

y3

# %% [markdown]
# # End of Group Work.
# ### Pick instruction up here

# %% [markdown]
# ### Join this back to data1 - let's go ahead and overwrite data1 for our purposes but in practice you may create a new df called data2

# %%
print(data1.shape)

data1 = data1.merge(y3, on = ['my_group','collsymb'], how = 'left')
# alt version
# data1 = data1.merge(y3, left_on = ['my_group','collsymb'], right_on = ['my_group','collsymb'], how = 'left')

print(data1.shape)

eda_table(data1,'coll_symb_ntile')

# %% [markdown]
# ### We still have some null, so let's put that at 50

# %%
fillna(data1,'coll_symb_ntile','coll_symb_ntile',specific_value = 50)
remove_list.append('my_group')
remove_list.append('collsymb')
stuff_to_analyze.remove('collsymb')

eda_table(data1,'coll_symb_ntile')

# %%
stuff_to_analyze

# %%
eda_table(data1,'perslimbi')

# %% [markdown]
# ### Let's see if we need both per person and per occurrence limits

# %%
data1.groupby(['perslimbi','acclimbi']).agg({'ee_bi': 'sum'}).reset_index()

# %% [markdown]
# ### The only interesting situation is the 300/300 and 300/500
# ### Let's see if it will be worth keeping them separate

# %%
eda_table(data1.loc[data1['perslimbi'] == 300000],'acclimbi')

# %% [markdown]
# # Group Work

# %% [markdown]
# ### Lesson 2 Exercise 1
# #### 1) create a new column 'limit_bi' by dividing 'perslimbi' by 1000 and rounding to the nearest integer
# #### 2) fill NaN values using the fillna() function, allow default behavior
# #### 3) limit the range to between 50 and 1000
# #### 4) add 'perslimbi' and 'acclimbi' to remove_list
# #### 5) remove 'perslimbi' and 'acclimbi' from stuff_to_analyze
# #### 6) run eda_table function on 'limit_bi'

# %%
# Solution goes here and in below cells

# %%
stuff_to_analyze

# %%
eda_table(data1,'deductiblecol')

# %% [markdown]
# ### Based on this distribution, let's put everything under 350 into 250, 500 is alone, and 750 with 1000 and above

# %%
data1['ded_coll'] = 250
nxt = data1['deductiblecol'] >= 500
data1.loc[nxt,'ded_coll'] = 500
nxt = data1['deductiblecol'] >= 750
data1.loc[nxt,'ded_coll'] = 1000

data1.groupby(['ded_coll','deductiblecol']).agg({'ee_col': 'sum'}).reset_index()

# %%
remove_list.append('deductiblecol')
stuff_to_analyze.remove('deductiblecol')

# %%
stuff_to_analyze

# %% [markdown]
# ### We need pol_eff_date for a later merge but not pol_exp_date

# %%
remove_list.append('pol_exp_date')

stuff_to_analyze.remove('pol_eff_date')
stuff_to_analyze.remove('pol_exp_date')

# %%
stuff_to_analyze

# %%
eda_table(data1,'pol_eff_year')

# %% [markdown]
# ### Nothing to do here, let's keep going

# %%
stuff_to_analyze.remove('pol_eff_year')

# %%
stuff_to_analyze

# %%
eda_table(data1,'DrvAge')

# %% [markdown]
# ### Age 16 has no losses for BI, let's go with 17 as the bottom to keep this simple
# ### Age 80 seems like a reasonable point to end the range
# ### For the null value let's use the mean rounded to nearest whole number

# %%
box_var(data1,'DrvAge',17,80,'DrvAge_box')

remove_list.append('DrvAge')
stuff_to_analyze.remove('DrvAge')

fillna(data1, 'DrvAge_box', 'DrvAge_box', specific_value = round(data1['DrvAge_box'].mean(),0))

eda_table(data1,'DrvAge_box')

# %%
stuff_to_analyze

# %%
eda_table(data1,'DrvSex')

# %% [markdown]
# ### Let's make a flag for male

# %%
data1['male'] = np.where(data1['DrvSex'] == 'M', True, False)

remove_list.append('DrvSex')
stuff_to_analyze.remove('DrvSex')

eda_table(data1,'male')

# %%
stuff_to_analyze

# %%
eda_table(data1,'DrvMarSts')

# %% [markdown]
# ### Let's create flags for single and widowed

# %%
data1['single'] = np.where(data1['DrvMarSts'] == 'S', True, False)
data1['widowed'] = np.where(data1['DrvMarSts'] == 'W', True, False)

remove_list.append('DrvMarSts')
stuff_to_analyze.remove('DrvMarSts')

eda_table(data1,'single')

# %%
eda_table(data1,'widowed')

# %%
stuff_to_analyze

# %%
eda_table(data1,'color_exterior')

# %% [markdown]
# ### Interesting to think about, but regulators don't accept color being used in rating, so let's remove these

# %%
remove_list.append('color_exterior')
remove_list.append('color_interior')

stuff_to_analyze.remove('color_exterior')
stuff_to_analyze.remove('color_interior')

# %%
stuff_to_analyze

# %% [markdown]
# ### year_CEF is an internal only field - let's remove it

# %%
remove_list.append('year_CEF')
stuff_to_analyze.remove('year_CEF')

# %%
stuff_to_analyze

# %%
eda_table(data1,'mDrvGenMarSts')

# %% [markdown]
# ### This is a combination of gender and marital status; let's continue our treatment of each individually and remove this

# %%
remove_list.append('mDrvGenMarSts')
stuff_to_analyze.remove('mDrvGenMarSts')

# %%
stuff_to_analyze

# %% [markdown]
# ### rand is an unneeded random number so let's remove it
# ### zip will be needed to merge data
# ### pol_id will be needed to make aggregated policy stats like max and min driver age
# ### vin_id will be needed to merge data

# %%
remove_list.append('rand')
stuff_to_analyze.remove('rand')

# %% [markdown]
# ## Create new dataframe as copy of original and remove unneeded fields

# %%
remove_list

# %%
[i for i in data1.columns if i not in remove_list and i not in facts]

# %%
data2 = data1[([i for i in data1.columns if i not in remove_list])].copy()

print(data1.shape)
print(data2.shape)

# %% [markdown]
# ## Minimize datatypes
#
# ### let's choose the minimum datatype to save memory
# ### first, look at dtypes

# %%
data2.dtypes

# %% [markdown]
# ### Now, what is the range of values for each of these?

# %%
for i in [i for i in data2.columns]:
    print(i + ' min = ' + str(data2[i].min()) + ', max = ' + str(data2[i].max()))

# %% [markdown]
# ### Which ones have decimal values?

# %%
float_list = []
for i in [i for i in data2.columns]:
    a = data2[([i])].drop_duplicates()
    a['rounded'] = round(a[i],0)
    a['rounded_diff'] = np.where(a['rounded'] != a[i],1 ,0)
    b = a.loc[a['rounded_diff'] == 1]

    if b.shape[0] > 0:
        print(i)
        print(b.head())

        float_list.append(i)

# %% [markdown]
# ### WHOOPS - there is a date in there which we can't round
# ### Let's try this again with some error handling

# %%
float_list = []
for i in [i for i in data2.columns]:
    try:
        a = data2[([i])].drop_duplicates()
        a['rounded'] = round(a[i],0)
        a['rounded_diff'] = np.where(a['rounded'] != a[i],1 ,0)
        b = a.loc[a['rounded_diff'] == 1]

        if b.shape[0] > 0:
            print(i)
            print(b.head())

            float_list.append(i)
    except:
        pass

# %%
float_list

# %% [markdown]
# ### Since all minimums besides the float_list items are non-negative, we can use uint instead of int
#
# ### Max values by type:
#
# ##### uint8, uint16, uint32
# ##### 255,   65535, 4294967295
#
# ### Let's make lists of fields based on max value and minimum datatype

# %%
remaining = [i for i in data2.columns if i not in float_list and i != 'pol_eff_date']
remaining

# %%
uint8_list = []
uint16_list = []
uint32_list = []
error_list = []

for r in remaining:
    if data2[r].max() <= 255:
        uint8_list.append(r)
    elif (data2[r].max() <= 65535) & (data2[r].max() > 255):
        uint16_list.append(r)
    elif (data2[r].max() <= 4294967295) & (data2[r].max() > 65535):
        uint32_list.append(r)
    else:
        error_list.append(r)

print(uint8_list)
print(uint16_list)
print(uint32_list)
print(error_list)

# %% [markdown]
# ### Make function to change datatype
# ### Only need to do float, unit8, and uin16 because uint32_list and error_list are empty
# ### Let's make a list of lists and the dtype we want to cast it to

# %%
print('Before: ' + str(round(data2.memory_usage(deep=True).sum()/1024**3,3)))

def cast_dtyp(data,field,dtyp):
    data[field] = data[field].astype(dtyp)


mod_list = [float_list, uint8_list, uint16_list]
dtyp_list = ['float64','uint8','uint16']

for i, lst in enumerate(mod_list):
    for h in lst:
        cast_dtyp(data2,h,dtyp_list[i])

print('After: ' + str(round(data2.memory_usage(deep=True).sum()/1024**3,3)))

# %% [markdown]
# # Group Work:

# %% [markdown]
# ## Merge CARFAX data & geodemographic data and check join quality
#
# ### let's see what we have in the carfax vehicle history data

# %%
[i for i in cfax.columns]

# %% [markdown]
# ### Year and LOO_days are not needed
# ### Let's analyze the rest after merging to determine if any others can be removed

# %%
cfax_remove_list = ['Year', 'LOO_days']
for i in cfax_remove_list:
    del cfax[i]

# %% [markdown]
# ### Now let's merge data2 and cfax, making sure the join is correct
# ### First, try inner join and check total records plus duplicates
# ### Before we do that, let's understand vin_id from data2

# %%
print(data2.shape[0])
print(data2[(['vin_id'])].drop_duplicates().shape[0])

# %% [markdown]
# ### So vin_id is repeated, which makes sense as we have multiple policy terms of the same vin
# ### Let's see if cfax data is distint

# %%
print(cfax.shape[0])
print(cfax[(['vin_id'])].drop_duplicates().shape[0])

# %% [markdown]
# ### It's not - let's see if pol_eff_date and Date will work

# %%
print(data2.shape[0])
print(data2[(['pol_eff_date','vin_id'])].drop_duplicates().shape[0])

# %%
print(cfax.shape[0])
print(cfax[(['Date','vin_id'])].drop_duplicates().shape[0])

# %% [markdown]
# ### Looks like it will join properly, however inner join won't work because cfax data doesn't exist for every single set of keys
# ### Let's do a left join and clean up the dtypes and null values later

# %%
cfax['Date'] = pd.to_datetime(cfax['Date'], infer_datetime_format = True)

print(data2.shape)

left_keys = ['pol_eff_date','vin_id']
right_keys = ['Date','vin_id']

data3 = data2.merge(cfax, left_on = left_keys, right_on = right_keys, how = 'left')

print(data3.shape)

# %% [markdown]
# ### GREAT - we got a good join
# ### Did all 98,566 cfax records actually get into data3?
# ### Let's try this again in a way that allows us to figure that out

# %%
cfax['cfax_join'] = 1

print(data2.shape)

left_keys = ['pol_eff_date','vin_id']
right_keys = ['Date','vin_id']

data3 = data2.merge(cfax, left_on = left_keys, right_on = right_keys, how = 'left')

print(data3.shape)

print(data3['cfax_join'].sum())

# %% [markdown]
# ### YES, it worked
# ### We can delete that field

# %%
del data3['cfax_join']

# %% [markdown]
# ### Now to the geo data

# %%
geo.head()

# %%
[i for i in geo.columns]

# %% [markdown]
# ### This is a ton of stuff
# ### Let's choose the best looking 4 for our purposes - in practice we would evaluate the signal on everything

# %%
geo_keep = ['Zip','wtd_avg_travel_time','Education Attainment, High School (Pop 25+)_ntile_pct_pop25','Population Density_ntile','Employment; % unemployment_ntile']

geo_to_join = geo[(geo_keep)].copy()

print(geo_to_join.shape)
geo_to_join.head()

# %% [markdown]
# ### Now we need to join it
# ### Let's see if we can make the key the exact same

# %%
data3.head()

# %% [markdown]
# ### We need to rename Zip to zip in geo_to_join
# ### Let's also rename these to shorter names

# %%
geo_to_join.rename(columns = {
    'Zip': 'zip',
    'Education Attainment, High School (Pop 25+)_ntile_pct_pop25': 'diploma_ntile',
    'Population Density_ntile': 'pop_density_ntile',
    'Employment; % unemployment_ntile': 'unemployment_ntile'
}
                   , inplace = True)

geo_to_join.head()

# %% [markdown]
# ### Same as before, let's evaluate the distinct zip counts

# %%
print(data3[(['zip'])].drop_duplicates().shape[0])
print(geo_to_join[(['zip'])].drop_duplicates().shape[0])

# %% [markdown]
# ### Oh, well that's obvious. data3 only contains data from Ohio, so of course we won't have the same counts
# ### Let's do an inner join and see how that works

# %%
print(data3.shape)

data4 = data3.merge(geo_to_join, on = ['zip'])

print(data4.shape)

# %% [markdown]
# ### Okay so it looks like a mismatch of datatypes.  Let's figure out what to change

# %%
data3['zip'].dtypes

# %%
geo_to_join['zip'].dtypes

# %% [markdown]
# ### Let's fix it

# %%
cast_dtyp(geo_to_join,'zip','uint16')

# %% [markdown]
# ### Let's try the merge again

# %%
print(data3.shape)

data4 = data3.merge(geo_to_join, on = ['zip'])

print(data4.shape)

# %% [markdown]
# ### Inner join wasn't good enough because we have less records now
# ### No problem, we can left join and just like with cfax data fix the nulls later

# %%
print(data3.shape)

data4 = data3.merge(geo_to_join, on = ['zip'], how = 'left')

print(data4.shape)

# %% [markdown]
# ### We can now get rid of pol_eff_date

# %%
del data4['pol_eff_date']

# %% [markdown]
# # Saving files - for reference

# %% [markdown]
# ## Save as .csv, .pkl, .ftr and check space on disk + import time

# %% [markdown]
# ### Feather is preferred for security, ability to read in R, performance

# %%
save_path = ''

data4.to_csv(save_path + 'data4.csv', index = False)
data4.to_pickle(save_path + 'data4.pkl')
data4.to_feather(save_path + 'data4.ftr')

# %% [markdown]
# ### Let's see how long each takes to import
# ### First, some basics on time measurements

# %%
import time
from datetime import datetime

t1 = datetime.now()
time.sleep(1)
t2 = datetime.now()

print((t2 - t1).microseconds)

# %%
t1 = datetime.now()
data4 = pd.read_csv(save_path + 'data4.csv')
t2 = datetime.now()

print('data4.csv: ' + str((t2 - t1).microseconds))

t1 = datetime.now()
data4 = pd.read_pickle(save_path + 'data4.pkl')
t2 = datetime.now()

print('data4.pkl: ' + str((t2 - t1).microseconds))

t1 = datetime.now()
data4 = pd.read_feather(save_path + 'data4.ftr')
t2 = datetime.now()

print('data4.ftr: ' + str((t2 - t1).microseconds))

# %% [markdown]
# ### Let's see which versions maintained our dtypes upon import

# %%
data4 = pd.read_csv(save_path + 'data4.csv')
data4.dtypes

# %%
data4 = pd.read_pickle(save_path + 'data4.pkl')
data4.dtypes

# %%
data4 = pd.read_feather(save_path + 'data4.ftr')
data4.dtypes

# %% [markdown]
# ### Export to SQL and import from SQL
# #### Make sure to specify schema = dbo to avoid the table ending up in your personal schema

# %%
import sqlalchemy
import urllib

params = urllib.parse.quote_plus("DRIVER={SQL Server};SERVER=DOTD01P;DATABASE=bootcamp;Trusted_Connection=yes")
engine = sqlalchemy.create_engine("mssql+pyodbc:///?odbc_connect=%s" % params)
engine.connect()

data4.to_sql(name='data4', schema = 'dbo', con=engine, index = False, if_exists = 'replace')

# %%
import pyodbc

conn = pyodbc.connect('''DRIVER={SQL Server};SERVER=DOTD01P;DATABASE=bootcamp;Trusted_Connection=yes''')
qry = '''select * from bootcamp.dbo.data4'''

t1 = datetime.now()
data4 = pd.read_sql(qry, conn)
t2 = datetime.now()

print('data4.sql: ' + str((t2 - t1).microseconds))

data4.dtypes
